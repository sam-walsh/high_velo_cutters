# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('fg_prospects.csv')

# %%
df = df.dropna(subset=['CMD'])
df.head()
# Out:
#                 Name   Pos  Org  Top 100  Org Rk        Age TJ Date  \
# 0  Grayson Rodriguez    SP  BAL     10.0       2  21.897222     NaN
# 1          Max Meyer    SP  MIA     19.0       1  22.575000     NaN
# 2          D.L. Hall  MIRP  BAL     28.0       3  23.055556     NaN
# 3           Asa Lacy    SP  KCR     29.0       2  22.352778     NaN
# 4        Jack Leiter    SP  TEX     31.0       1  21.222222     NaN
#
#      FB Type       FB       SL       CB       CH      CMD  RPM FB  RPM Break  \
# 0       Tail  60 / 60  50 / 55  55 / 55  55 / 60  40 / 50  2400.0     2650.0
# 1  Sink/Tail  55 / 60  60 / 60      NaN  45 / 55  30 / 45  2600.0     2600.0
# 2       Tail  60 / 60      NaN  55 / 60  55 / 60  30 / 40  2400.0     2500.0
# 3       Rise  60 / 70  60 / 70  55 / 60  45 / 50  30 / 45  2200.0     2400.0
# 4       Rise  55 / 60  50 / 55  55 / 55  40 / 55  30 / 55  2100.0     2250.0
#
#     Sits   Tops  FV   playerId
# 0  90-95   97.0  60  sa3008130
# ...

# %%
df.loc[df['FB Type'].isin(['Cut', 'Cut/Rise'])].groupby('Org')['Org'].count()
# Out:
# Org
# ARI    4
# ATL    1
# BAL    1
# BOS    1
# CHC    1
# CHW    1
# CIN    1
# COL    1
# DET    1
# HOU    5
# MIN    2
# NYM    2
# NYY    2
# PHI    1
# PIT    2
# SFG    3
# STL    2
# TBR    4
# Name: Org, dtype: int64

# %%
df.loc[df['FB Type'] == 'Sink'].groupby('Org')['Org'].count()
# Out:
# Org
# ARI    2
# ATL    1
# BAL    2
# BOS    1
# CHC    1
# CHW    3
# CIN    1
# CLE    3
# COL    1
# KCR    4
# LAA    1
# LAD    6
# MIA    1
# MIL    2
# MIN    4
# NYM    1
# NYY    3
# OAK    1
# PHI    5
# PIT    4
# SDP    1
# SFG    4
# STL    4
# TBR    1
# TOR    3
# WSN    2
# Name: Org, dtype: int64

# %%
df[['CMD PV','CMD FV']] = df.CMD.str.split(' / ', expand=True).astype(int)

# %%
df.groupby('Org')['RPM FB', 'RPM Break', 'CMD FV'].mean().sort_values('RPM Break', ascending=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#           RPM FB    RPM Break     CMD FV
# Org
# STL  2138.888889  2656.250000  46.333333
# BOS  2323.684211  2555.000000  45.185185
# SFG  2363.888889  2537.500000  46.153846
# HOU  2340.625000  2534.375000  43.000000
# NYY  2368.750000  2525.000000  48.250000
# MIN  2206.666667  2525.000000  49.210526
# MIL  2220.000000  2522.222222  44.444444
# CHC  2270.454545  2520.000000  45.483871
# SDP  2327.777778  2511.111111  48.636364
# NYM  2346.153846  2506.250000  45.000000
# LAA  2288.888889  2504.545455  43.653846
# OAK  2215.000000  2493.750000  45.312500
# COL  2260.714286  2490.000000  45.277778
# CLE  2241.666667  2478.125000  49.772727
# TOR  2346.428571  2465.384615  46.250000
# BAL  2305.555556  2462.500000  47.500000
# ...

# %%
help(df.CMD.str.split)
# Out:
# Help on method split in module pandas.core.strings.accessor:
#
# split(pat=None, n=-1, expand=False) method of pandas.core.strings.accessor.StringMethods instance
#     Split strings around given separator/delimiter.
#
#     Splits the string in the Series/Index from the beginning,
#     at the specified delimiter string. Equivalent to :meth:`str.split`.
#
#     Parameters
#     ----------
#     pat : str, optional
#         String or regular expression to split on.
#         If not specified, split on whitespace.
#     n : int, default -1 (all)
#         Limit number of splits in output.
#         ``None``, 0 and -1 will be interpreted as return all splits.
#     expand : bool, default False
#         Expand the split strings into separate columns.
#
#         * If ``True``, return DataFrame/MultiIndex expanding dimensionality.
#         * If ``False``, return Series/Index, containing lists of strings.
#
#     Returns
#     -------
#     Series, Index, DataFrame or MultiIndex
# ...
